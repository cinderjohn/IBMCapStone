# %% [markdown]
# # Start a Business in the US fastest growing city-San Antonio, TX
# San Antonio, TX enjoys the biggest growth in population in from 2016 to 2017. This provides business opportunities especially for entrepreneurs who want to open their business in San Antonio.
#
# ## The goal of this project is the following to identify which business opportunity(ies) would be the best to pursue based on the other big cities.
#
#
# Reference:
#
# https://www.forbes.com/sites/candaceevans/2018/07/13/largest-population-boom-in-the-country-is-in-san-antonio-texas-because-business/#71b491b72b4b
#
# ## Datasets
# ### San Antonio, TX Zipcode and population data:
#     https://github.com/cinderjohn/IBMCapStone/blob/master/San%20Antonio.csv
#
# ### Phoenix, AZ Zipcode and population data:
#     https://github.com/cinderjohn/IBMCapStone/blob/master/Phoenix.csv
#
# ### Coordinates of All US Zipcodes:
#     https://github.com/cinderjohn/IBMCapStone/blob/master/Geospatial_Coordinates.csv
#
# ### Foursquares venue information for San Antonio and Phoenix
#      In the code

# %%
#Utility Packages
import requests
import itertools
import pandas as pd
import numpy as np
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter

import matplotlib.ticker as ticker
from sklearn import preprocessing
# !conda install -c anaconda beautifulsoup4 -y
from bs4 import BeautifulSoup
import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes  
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe



# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes 
#!conda install -c conda-forge/label/cf201901 folium 
import folium # map rendering library


print('Packages ready!')
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following packages will be UPDATED:
#
#     beautifulsoup4: 4.6.0-py35h442a8c9_1 --> 4.6.3-py35_0 anaconda
#
# beautifulsoup4 100% |################################| Time: 0:00:00  38.75 MB/s
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.49-py_0   conda-forge
#     geopy:         1.18.1-py_0 conda-forge
#
# geographiclib- 100% |################################| Time: 0:00:00  24.90 MB/s
# geopy-1.18.1-p 100% |################################| Time: 0:00:00  37.11 MB/s
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     altair:  2.2.2-py35_1 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
# altair-2.2.2-p 100% |################################| Time: 0:00:00  51.23 MB/s
# branca-0.3.1-p 100% |################################| Time: 0:00:00  34.35 MB/s
# vincent-0.4.4- 100% |################################| Time: 0:00:00  39.00 MB/s
# folium-0.5.0-p 100% |################################| Time: 0:00:00  46.53 MB/s
# Packages ready!

# %%
#!conda install -c conda-forge =0.5.0 --yes

# %%
#import folium # map rendering library

# %%
## Define Foursquare Credentials and Version
CLIENT_ID = 'A0BEEBP0VG14B2EDHXDUX1YYNR0O5RLUV3CNMBUVX4UBOSGZ' # your Foursquare ID
CLIENT_SECRET = '3HELNYYP3L5ESUUC5RXE2ARB1HQQSQO4UOQQN2SOZB51T1DJ' # your Foursquare Secret
VERSION = '20180604'

# %%
address = 'San Antonio, TX'

geolocator = Nominatim()
sa = geolocator.geocode(address)
latitude = sa.latitude
longitude = sa.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ipykernel/__main__.py:3: DeprecationWarning: Using Nominatim with the default "geopy/1.18.1" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   app.launch_new_instance()
# The geograpical coordinate of Toronto are 29.4246002, -98.4951405.

# %%
## read in SA, PHX and coordinates
sa_df = pd.read_csv('https://raw.githubusercontent.com/cinderjohn/IBMCapStone/Data/San%20Antonio%20Zip.csv')
phx_df = pd.read_csv('https://raw.githubusercontent.com/cinderjohn/IBMCapStone/master/Phoenix.csv')
zip_coordinate_df = pd.read_csv('https://raw.githubusercontent.com/cinderjohn/IBMCapStone/master/US%20Zip%20Code%20Geolocations%20from%202018%20Government%20Datal.csv')
zip_coordinate_df.dtypes
# Out:
# ZIP      int64
# LAT    float64
# LNG    float64
# dtype: object

# %%
phx_df.dtypes
sa_df.dtypes
# Out:
# Zip            int64
# City          object
# County        object
# Population    object
# dtype: object

# %%
# create map of Toronto using latitude and longitude values
map_sa = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
#for lat, lng, borough, neighborhood in zip(merged_df['Latitude'], merged_df['Longitude'], merged_df['Borough'], merged_df['Neighborhood']):
#    label = '{}, {}'.format(neighborhood, borough)
#    label = folium.Popup(label, parse_html=True)
#    folium.CircleMarker(
#        [lat, lng],
#        radius=5,
#        popup=label,
#        color='red',
#        fill=True,
#        fill_color='#2156cc',
#        fill_opacity=0.5,
#        parse_html=False).add_to(map_toronto)  
    
map_sa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
sa_df.head()
phx_df.head()
zip_coordinate_df.head()
# Out:
#    ZIP        LAT        LNG
# 0  601  18.180555 -66.749961
# 1  602  18.361945 -67.175597
# 2  603  18.455183 -67.119887
# 3  606  18.158327 -66.932928
# 4  610  18.295366 -67.125135

# %%
sa_df['Population'] = sa_df['Population'].str.replace(',', '')
phx_df['Population'] = phx_df['Population'].str.replace(',', '')

# %%
sa_df['Population']=sa_df['Population'].apply(lambda x:float(x))
phx_df['Population']=phx_df['Population'].apply(lambda x:float(x))

# %%
sa_df.dtypes
phx_df.dtypes
# Out:
# Zip             int64
# City           object
# County         object
# Population    float64
# dtype: object

# %%
#Merge Coordinate with the city zip population data
sa_merged_df = pd.merge(sa_df, zip_coordinate_df,left_on='Zip',right_on='ZIP',how='left').drop('ZIP', axis=1)
phx_merged_df = pd.merge(phx_df, zip_coordinate_df,left_on='Zip',right_on='ZIP',how='left').drop('ZIP', axis=1)

# %%
sa_df_final = sa_merged_df[np.isfinite(sa_merged_df['LAT'])]
phx_df_final = phx_merged_df[np.isfinite(phx_merged_df['LAT'])]
sa_df_final.dtypes
# Out:
# Zip             int64
# City           object
# County         object
# Population    float64
# LAT           float64
# LNG           float64
# dtype: object

# %%
sa_df_final['Zip'] = sa_df_final['Zip'].apply(str)
phx_df_final['Zip'] = phx_df_final['Zip'].apply(str)
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
print(phx_df_final.dtypes)
phx_df_final.head()
# Out:
# Zip            object
# City           object
# County         object
# Population    float64
# LAT           float64
# LNG           float64
# dtype: object
#      Zip     City    County  Population        LAT         LNG
# 2  85003  Phoenix  Maricopa      9369.0  33.450662 -112.078353
# 3  85004  Phoenix  Maricopa      4965.0  33.451567 -112.069886
# 5  85006  Phoenix  Maricopa     25742.0  33.465234 -112.048771
# 6  85007  Phoenix  Maricopa     14040.0  33.447614 -112.090883
# 7  85008  Phoenix  Maricopa     56145.0  33.462954 -111.985178

# %%
sa_df_final.columns = ['Zipcode','City','County',
                     'Population','latitude','longitude']
phx_df_final.columns = ['Zipcode','City','County',
                     'Population','latitude','longitude']
sa_df_final['Zipcode']='SA' + sa_df_final['Zipcode'].astype(str)
phx_df_final['Zipcode']='PHX' + phx_df_final['Zipcode'].astype(str)
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
latitude = phx_df_final.loc[5, 'latitude'] # neighborhood latitude value
longitude = phx_df_final.loc[5, 'longitude'] # neighborhood longitude value
map_phx = folium.Map(location=[latitude, longitude], zoom_start=10)
for lat, lng, borough, neighborhood in zip(phx_df_final['latitude'], phx_df_final['longitude'], phx_df_final['Zipcode'], phx_df_final['City']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='#3156cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_phx)  
    
map_phx
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_sa = folium.Map(location=[latitude, longitude], zoom_start=10)
for lat, lng, borough, neighborhood in zip(sa_df_final['latitude'], sa_df_final['longitude'], sa_df_final['Zipcode'], sa_df_final['City']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='#2156cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_sa)  
    
map_sa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
merged_df=pd.concat([sa_df_final, phx_df_final])

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
sa_df_final[sa_df_final['Zipcode']=='SA78209'].index
# Out:
# Int64Index([8], dtype='int64')

# %%
neighborhood_latitude = sa_df_final.loc[8, 'latitude'] # neighborhood latitude value
neighborhood_longitude = sa_df_final.loc[8, 'longitude'] # neighborhood longitude value

neighborhood_name = sa_df_final.loc[8, 'Zipcode'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of SA78209 are 29.488906, -98.45623499999999.

# %%
LIMIT = 150
radius = 500
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=A0BEEBP0VG14B2EDHXDUX1YYNR0O5RLUV3CNMBUVX4UBOSGZ&client_secret=3HELNYYP3L5ESUUC5RXE2ARB1HQQSQO4UOQQN2SOZB51T1DJ&ll=33.465234,-112.048771&v=20180604&radius=500&limit=150'

# %%
results = requests.get(url).json()
#results

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)
# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]
print(nearby_venues.head())
# Out:
#                                 name  categories        lat         lng
# 0  Ollie Vaughn's Kitchen and Bakery        Café  33.465964 -112.048779
# 1                        Smooth Brew        Café  33.465552 -112.049990
# 2                         Guanaquito  Restaurant  33.465945 -112.050643
# 3                     Rainbow Donuts  Donut Shop  33.465534 -112.052255
# 4                       La Santisima  Taco Place  33.469189 -112.047502

# %%
## create a function to repeat the same process to all the neighborhoods in Toronto

def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'categories']
    
    return(nearby_venues)

# %%
# find the venues in all SA Zipcodes
all_venue_df = getNearbyVenues(names=merged_df['Zipcode'],
                                   latitudes=merged_df['latitude'],
                                   longitudes=merged_df['longitude']
                                  )
# Out:
# SA78201
# SA78202
# SA78203
# SA78204
# SA78205
# SA78207
# SA78208
# SA78209
# SA78210
# SA78211
# SA78212
# SA78213
# SA78214
# SA78215
# SA78216
# SA78217
# SA78218
# SA78219
# SA78220
# SA78221
# SA78222
# SA78223
# SA78224
# SA78225
# SA78226
# SA78227
# SA78228
# SA78229
# SA78230
# SA78231
# SA78232
# SA78233
# SA78234
# SA78235
# SA78236
# SA78237
# SA78238
# SA78239
# SA78240
# SA78242
# SA78243
# SA78244
# SA78245
# SA78247
# SA78248
# SA78249
# SA78250
# SA78251
# SA78252
# SA78253
# SA78254
# SA78255
# SA78256
# SA78257
# SA78258
# SA78259
# SA78260
# SA78261
# SA78263
# SA78264
# SA78266
# PHX85003
# PHX85004
# PHX85006
# PHX85007
# PHX85008
# PHX85009
# PHX85012
# PHX85013
# PHX85014
# PHX85015
# PHX85016
# PHX85017
# PHX85018
# PHX85019
# PHX85020
# PHX85021
# PHX85022
# PHX85023
# PHX85024
# PHX85027
# PHX85028
# PHX85029
# PHX85031
# PHX85032
# PHX85033
# PHX85034
# PHX85035
# PHX85037
# PHX85040
# PHX85041
# PHX85042
# PHX85043
# PHX85044
# PHX85045
# PHX85048
# PHX85050
# PHX85051
# PHX85053
# PHX85054
# PHX85083
# PHX85085
# PHX85086
# PHX85087

# %%
all_venue_df.shape
all_venue_df.head()
# Out:
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0      SA78201              29.468413              -98.528889
# 1      SA78201              29.468413              -98.528889
# 2      SA78201              29.468413              -98.528889
# 3      SA78201              29.468413              -98.528889
# 4      SA78201              29.468413              -98.528889
#
#                            Venue  Venue Latitude  Venue Longitude  \
# 0      Jacala Mexican Restaurant       29.468267       -98.525847
# 1  La Taqueria Huentitan Jalisco       29.467041       -98.528436
# 2                      Starbucks       29.466226       -98.527546
# 3         De Wese's Tip Top Cafe       29.470214       -98.531357
# 4               Church's Chicken       29.466726       -98.525842
#
#             categories
# 0   Mexican Restaurant
# 1   Mexican Restaurant
# 2          Coffee Shop
# 3                 Café
# 4  Fried Chicken Joint

# %%
## check how many venues were returned for each Zipcode
all_venue_df.groupby('Neighborhood').count()
# Out:
#               Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# PHX85003                         29                      29     29
# PHX85004                         72                      72     72
# PHX85006                         16                      16     16
# PHX85007                          8                       8      8
# PHX85008                         10                      10     10
# PHX85009                          2                       2      2
# PHX85012                         59                      59     59
# PHX85013                         21                      21     21
# PHX85014                         12                      12     12
# PHX85015                          6                       6      6
# PHX85016                         37                      37     37
# PHX85017                          8                       8      8
# PHX85018                         11                      11     11
# PHX85019                          4                       4      4
# PHX85020                          4                       4      4
# PHX85021                          5                       5      5
# PHX85022                          3                       3      3
# PHX85023                          4                       4      4
# PHX85027                          2                       2      2
# PHX85028                          1                       1      1
# PHX85029                          4                       4      4
# PHX85031                         20                      20     20
# PHX85032                          4                       4      4
# PHX85033                          1                       1      1
# PHX85034                          7                       7      7
# PHX85037                          1                       1      1
# PHX85040                          4                       4      4
# PHX85041                          2                       2      2
# PHX85042                          3                       3      3
# PHX85043                          3                       3      3
# ...                             ...                     ...    ...
# SA78224                           1                       1      1
# SA78225                          13                      13     13
# SA78226                           5                       5      5
# SA78227                          31                      31     31
# SA78228                           4                       4      4
# SA78229                           2                       2      2
# SA78230                           6                       6      6
# SA78231                           2                       2      2
# SA78232                          15                      15     15
# SA78233                           4                       4      4
# SA78234                           8                       8      8
# SA78235                           2                       2      2
# SA78236                           6                       6      6
# SA78237                           1                       1      1
# SA78238                          76                      76     76
# SA78239                           2                       2      2
# SA78240                           6                       6      6
# SA78242                           4                       4      4
# SA78243                           4                       4      4
# SA78244                           1                       1      1
# SA78245                           1                       1      1
# SA78247                           4                       4      4
# SA78248                          15                      15     15
# SA78249                           2                       2      2
# SA78250                          10                      10     10
# SA78251                          11                      11     11
# SA78257                           1                       1      1
# SA78258                           2                       2      2
# SA78259                           1                       1      1
# SA78260                           1                       1      1
#
#               Venue Latitude  Venue Longitude  categories
# Neighborhood
# PHX85003                  29               29          29
# PHX85004                  72               72          72
# PHX85006                  16               16          16
# PHX85007                   8                8           8
# PHX85008                  10               10          10
# PHX85009                   2                2           2
# PHX85012                  59               59          59
# PHX85013                  21               21          21
# PHX85014                  12               12          12
# PHX85015                   6                6           6
# PHX85016                  37               37          37
# PHX85017                   8                8           8
# PHX85018                  11               11          11
# PHX85019                   4                4           4
# PHX85020                   4                4           4
# PHX85021                   5                5           5
# PHX85022                   3                3           3
# PHX85023                   4                4           4
# PHX85027                   2                2           2
# PHX85028                   1                1           1
# PHX85029                   4                4           4
# PHX85031                  20               20          20
# PHX85032                   4                4           4
# PHX85033                   1                1           1
# PHX85034                   7                7           7
# PHX85037                   1                1           1
# PHX85040                   4                4           4
# PHX85041                   2                2           2
# PHX85042                   3                3           3
# PHX85043                   3                3           3
# ...                      ...              ...         ...
# SA78224                    1                1           1
# SA78225                   13               13          13
# SA78226                    5                5           5
# SA78227                   31               31          31
# SA78228                    4                4           4
# SA78229                    2                2           2
# SA78230                    6                6           6
# SA78231                    2                2           2
# SA78232                   15               15          15
# SA78233                    4                4           4
# SA78234                    8                8           8
# SA78235                    2                2           2
# SA78236                    6                6           6
# SA78237                    1                1           1
# SA78238                   76               76          76
# SA78239                    2                2           2
# SA78240                    6                6           6
# SA78242                    4                4           4
# SA78243                    4                4           4
# SA78244                    1                1           1
# SA78245                    1                1           1
# SA78247                    4                4           4
# SA78248                   15               15          15
# SA78249                    2                2           2
# SA78250                   10               10          10
# SA78251                   11               11          11
# SA78257                    1                1           1
# SA78258                    2                2           2
# SA78259                    1                1           1
# SA78260                    1                1           1
#
# [86 rows x 6 columns]

# %%
## Analyze Each Neighborhood

# one hot encoding
onehot = pd.get_dummies(all_venue_df[['categories']], prefix="", prefix_sep="")
print(onehot.columns)
# add neighborhood column back to dataframe
onehot['Neighborhood'] = all_venue_df['Neighborhood'] 

# move neighborhood column to the first column
column_list = onehot.columns.tolist()
column_number = int(column_list.index('Neighborhood'))
column_list = [column_list[column_number]] + column_list[:column_number] + column_list[column_number+1:]
# Out:
# Index(['Accessories Store', 'Airport Lounge', 'Airport Service',
#        'Airport Terminal', 'American Restaurant', 'Arcade', 'Art Gallery',
#        'Art Museum', 'Arts & Crafts Store', 'Asian Restaurant',
#        ...
#        'Vegetarian / Vegan Restaurant', 'Video Game Store', 'Video Store',
#        'Vietnamese Restaurant', 'Warehouse Store', 'Waterfront', 'Wine Bar',
#        'Wings Joint', 'Women's Store', 'Yoga Studio'],
#       dtype='object', length=218)

# %%
## group rows by neighborhood and by taking the mean of the frequency of occurrence of each category

grouped = onehot.groupby('Neighborhood').mean().reset_index()
grouped.shape
# Out:
# (86, 218)

# %%
## put that into a pandas dataframe
## First, write a function to sort the venues in descending order.

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]
## create the new dataframe and display the top 10 venues for each neighborhood.

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = grouped['Neighborhood']

for ind in np.arange(grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted
# Out:
#    Neighborhood       1st Most Common Venue 2nd Most Common Venue  \
# 0      PHX85003         American Restaurant           Music Venue
# 1      PHX85004                 Coffee Shop           Pizza Place
# 2      PHX85006          Mexican Restaurant            Taco Place
# 3      PHX85007                  Food Truck    Athletics & Sports
# 4      PHX85008                Burger Joint              Pharmacy
# 5      PHX85009          Mexican Restaurant         Auto Workshop
# 6      PHX85012                    Boutique           Pizza Place
# 7      PHX85013              Cosmetics Shop                  Park
# 8      PHX85014                 Pizza Place         Moving Target
# 9      PHX85015                 Record Shop   Fried Chicken Joint
# 10     PHX85016                 Coffee Shop   American Restaurant
# 11     PHX85017         Rental Car Location     Convenience Store
# 12     PHX85018                 Coffee Shop  Fast Food Restaurant
# 13     PHX85019             Automotive Shop        Rental Service
# 14     PHX85020          Mexican Restaurant         Bowling Alley
# 15     PHX85021                        Park   American Restaurant
# 16     PHX85022                       Trail           Yoga Studio
# 17     PHX85023                   Racetrack       Warehouse Store
# 18     PHX85027                  Bagel Shop             BBQ Joint
# 19     PHX85028                Intersection           Flea Market
# 20     PHX85029                   BBQ Joint            Hookah Bar
# 21     PHX85031        Fast Food Restaurant    Chinese Restaurant
# 22     PHX85032                        Park          Intersection
# 23     PHX85033                 Bus Station           Yoga Studio
# 24     PHX85034             Airport Service        Shipping Store
# 25     PHX85037          Italian Restaurant           Yoga Studio
# 26     PHX85040         American Restaurant          Burger Joint
# 27     PHX85041                Home Service           Yoga Studio
# 28     PHX85042              Cosmetics Shop              Mountain
# 29     PHX85043                Intersection           IT Services
# ..          ...                         ...                   ...
# 56      SA78224                     Stables           Flea Market
# 57      SA78225                 Video Store    Mexican Restaurant
# 58      SA78226                       Track      Airport Terminal
# 59      SA78227          Mexican Restaurant  Fast Food Restaurant
# 60      SA78228                 Music Store           Wings Joint
# 61      SA78229                       Hotel        Sandwich Place
# 62      SA78230                      Bakery           Pizza Place
# 63      SA78231               Grocery Store            Donut Shop
# 64      SA78232            Toy / Game Store              Dive Bar
# 65      SA78233             Warehouse Store                 Hotel
# 66      SA78234                         Gym  Fast Food Restaurant
# 67      SA78235           Convenience Store            Playground
# 68      SA78236                       Hotel             BBQ Joint
# 69      SA78237       General Entertainment           Flea Market
# 70      SA78238              Clothing Store            Shoe Store
# 71      SA78239                 IT Services                  Tree
# 72      SA78240               Grocery Store          Liquor Store
# 73      SA78242         American Restaurant        Discount Store
# 74      SA78243           Convenience Store        Sandwich Place
# 75      SA78244                        Pool           Yoga Studio
# 76      SA78245         Sporting Goods Shop           Yoga Studio
# 77      SA78247                 Gas Station           Video Store
# 78      SA78248        Gym / Fitness Center              Pharmacy
# 79      SA78249                         Gym                 Trail
# 80      SA78250                 Pizza Place                   Bar
# 81      SA78251         American Restaurant                Resort
# 82      SA78257            Insurance Office           Yoga Studio
# 83      SA78258                 Video Store                  Park
# 84      SA78259  Construction & Landscaping           Yoga Studio
# 85      SA78260                        Pool           Yoga Studio
#
#          3rd Most Common Venue   4th Most Common Venue  \
# 19        French Restaurant                Fountain            Food Truck
# 20   Furniture / Home Store      Frozen Yogurt Shop   Fried Chicken Joint
# 21        Mobile Phone Shop              Restaurant            Sports Bar
# 22      Fried Chicken Joint       French Restaurant              Fountain
# 23      Fried Chicken Joint       French Restaurant              Fountain
# 24        French Restaurant              Food Court            Food Truck
# 25      Fried Chicken Joint       French Restaurant              Fountain
# 26   Furniture / Home Store      Frozen Yogurt Shop   Fried Chicken Joint
# 27        French Restaurant                Fountain            Food Truck
# 28       Frozen Yogurt Shop     Fried Chicken Joint     French Restaurant
# 29      Fried Chicken Joint       French Restaurant              Fountain
# ..                      ...                     ...                   ...
# 56        French Restaurant                Fountain            Food Truck
# 57                BBQ Joint    Fast Food Restaurant        Discount Store
# 58   Furniture / Home Store      Frozen Yogurt Shop   Fried Chicken Joint
# 59         Greek Restaurant             Gas Station   Fried Chicken Joint
# 60   Furniture / Home Store      Frozen Yogurt Shop   Fried Chicken Joint
# 61      Fried Chicken Joint       French Restaurant              Fountain
# 62              Yoga Studio  Furniture / Home Store    Frozen Yogurt Shop
# 63      Fried Chicken Joint       French Restaurant              Fountain
# 64  Health & Beauty Service              Taco Place  Fast Food Restaurant
# 65      Fried Chicken Joint       French Restaurant              Fountain
# 66       Miscellaneous Shop             Flower Shop    Frozen Yogurt Shop
# 67      Fried Chicken Joint       French Restaurant              Fountain
# 68       Frozen Yogurt Shop     Fried Chicken Joint     French Restaurant
# 69        French Restaurant                Fountain            Food Truck
# 70            Women's Store        Department Store    Italian Restaurant
# 71      Fried Chicken Joint       French Restaurant              Fountain
# 72       Frozen Yogurt Shop     Fried Chicken Joint     French Restaurant
# 73              Gas Station  Furniture / Home Store    Frozen Yogurt Shop
# 74      Fried Chicken Joint       French Restaurant              Fountain
# 75      Fried Chicken Joint       French Restaurant              Fountain
# 76        French Restaurant                Fountain            Food Truck
# 77       Frozen Yogurt Shop     Fried Chicken Joint     French Restaurant
# 78       Chinese Restaurant             Dry Cleaner                   Spa
# 79      Fried Chicken Joint       French Restaurant              Fountain
# 80           Breakfast Spot             Gas Station    Frozen Yogurt Shop
# 81            Hot Dog Joint             Golf Course            Steakhouse
# 82      Fried Chicken Joint       French Restaurant              Fountain
# 83      Fried Chicken Joint       French Restaurant              Fountain
# 84      Fried Chicken Joint       French Restaurant              Fountain
# 85      Fried Chicken Joint       French Restaurant              Fountain
#
#    10th Most Common Venue
# 0               Rock Club
# 1      Salon / Barbershop
# 2                 Gay Bar
# 3             Flower Shop
# 4                    Pool
# 5                Fountain
# 6             Candy Store
# 7         Thai Restaurant
# 8            Dessert Shop
# 9       French Restaurant
# 10                    Spa
# 11               Creperie
# 12    Indie Movie Theater
# 13               Fountain
# 14               Fountain
# 15               Fountain
# 16             Food Truck
# 17      French Restaurant
# 18               Fountain
# 19             Food Court
# 20      French Restaurant
# 21              Pawn Shop
# 22             Food Truck
# 23             Food Truck
# 24               Fountain
# 25             Food Truck
# 26      French Restaurant
# 27             Food Court
# 28               Fountain
# 29             Food Truck
# ..                    ...
# 56             Food Court
# 57            Pizza Place
# 58      French Restaurant
# 59            Bus Station
# 60      French Restaurant
# 61             Food Truck
# 62    Fried Chicken Joint
# 63             Food Truck
# 64    Rental Car Location
# 65             Food Truck
# 66    Fried Chicken Joint
# 67             Food Truck
# 68               Fountain
# 69             Food Court
# 70       Toy / Game Store
# 71             Food Truck
# 72               Fountain
# 73    Fried Chicken Joint
# 74             Food Truck
# 75             Food Truck
# 76             Food Court
# 77               Fountain
# 78      Convenience Store
# 79             Food Truck
# 80    Fried Chicken Joint
# 81            Yoga Studio
# 82             Food Truck
# 83             Food Truck
# 84             Food Truck
# 85             Food Truck
#
# [86 rows x 11 columns]

# %%
## Cluster Neighborhoods
## Run k-means to cluster the neighborhood into 10 clusters.

# set number of clusters
kclusters = 10

grouped_clustering = grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[:].shape
# Out:
# (86,)

# %%
kmeans
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=10, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=0, tol=0.0001, verbose=0)

# %%
all_merged = merged_df.head(86)

# %%
all_merged['Cluster Labels']=kmeans.labels_
all_merged
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#      Zipcode         City    County  Population   latitude   longitude  \
# 0    SA78201  San Antonio     Bexar     45307.0  29.468413  -98.528889
# 1    SA78202  San Antonio     Bexar     11691.0  29.428169  -98.460881
# 2    SA78203  San Antonio     Bexar      6099.0  29.415100  -98.459123
# 3    SA78204  San Antonio     Bexar     11125.0  29.404404  -98.505028
# 4    SA78205  San Antonio     Bexar      1453.0  29.423945  -98.486420
# 6    SA78207  San Antonio     Bexar     55514.0  29.422124  -98.525978
# 7    SA78208  San Antonio     Bexar      3736.0  29.439819  -98.458549
# 8    SA78209  San Antonio     Bexar     39197.0  29.488906  -98.456235
# 9    SA78210  San Antonio     Bexar     36865.0  29.395776  -98.464401
# 10   SA78211  San Antonio     Bexar     31944.0  29.342550  -98.570024
# 11   SA78212  San Antonio     Bexar     28415.0  29.464611  -98.493653
# 12   SA78213  San Antonio     Bexar     40396.0  29.516395  -98.523017
# 13   SA78214  San Antonio     Bexar     23341.0  29.324786  -98.470039
# 14   SA78215  San Antonio     Bexar      1150.0  29.441258  -98.480498
# 15   SA78216  San Antonio     Bexar     40267.0  29.537264  -98.487882
# 16   SA78217  San Antonio     Bexar     32165.0  29.538074  -98.415198
# 17   SA78218  San Antonio     Bexar     31917.0  29.490048  -98.397135
# 18   SA78219  San Antonio     Bexar     15225.0  29.446686  -98.387465
# 19   SA78220  San Antonio     Bexar     15965.0  29.418151  -98.394314
# 20   SA78221  San Antonio     Bexar     35990.0  29.298640  -98.483115
# 21   SA78222  San Antonio     Bexar     19408.0  29.354940  -98.371889
# 22   SA78223  San Antonio     Bexar     50637.0  29.311940  -98.391006
# 23   SA78224  San Antonio     Bexar     17601.0  29.299225  -98.535354
# 24   SA78225  San Antonio     Bexar     13025.0  29.387990  -98.526028
# 25   SA78226  San Antonio     Bexar      6648.0  29.383778  -98.569940
# 26   SA78227  San Antonio     Bexar     46077.0  29.406624  -98.630303
# 27   SA78228  San Antonio     Bexar     58811.0  29.460646  -98.571279
# 28   SA78229  San Antonio     Bexar     28804.0  29.501861  -98.569302
# 29   SA78230  San Antonio     Bexar     39089.0  29.546515  -98.557207
# 30   SA78231  San Antonio     Bexar      7906.0  29.578541  -98.541904
# ..       ...          ...       ...         ...        ...         ...
# 59   SA78260  San Antonio     Bexar     24844.0  29.697453  -98.486728
# 60   SA78261  San Antonio     Bexar     13513.0  29.689580  -98.402411
# 61   SA78263  San Antonio     Bexar      4673.0  29.363661  -98.304351
# 62   SA78264  San Antonio     Bexar     12339.0  29.193200  -98.490789
# 64   SA78266  San Antonio     Comal      5591.0  29.650529  -98.338420
# 2   PHX85003      Phoenix  Maricopa      9369.0  33.450662 -112.078353
# 3   PHX85004      Phoenix  Maricopa      4965.0  33.451567 -112.069886
# 5   PHX85006      Phoenix  Maricopa     25742.0  33.465234 -112.048771
# 6   PHX85007      Phoenix  Maricopa     14040.0  33.447614 -112.090883
# 7   PHX85008      Phoenix  Maricopa     56145.0  33.462954 -111.985178
# 8   PHX85009      Phoenix  Maricopa     52520.0  33.443097 -112.128136
# 11  PHX85012      Phoenix  Maricopa      6390.0  33.507577 -112.070981
# 12  PHX85013      Phoenix  Maricopa     19314.0  33.511113 -112.084731
# 13  PHX85014      Phoenix  Maricopa     24782.0  33.507223 -112.057690
# 14  PHX85015      Phoenix  Maricopa     37644.0  33.508664 -112.102018
# 15  PHX85016      Phoenix  Maricopa     33896.0  33.513390 -112.029228
# 16  PHX85017      Phoenix  Maricopa     38872.0  33.508782 -112.123068
# 17  PHX85018      Phoenix  Maricopa     36065.0  33.505956 -111.985386
# 18  PHX85019      Phoenix  Maricopa     25042.0  33.508109 -112.144920
# 19  PHX85020      Phoenix  Maricopa     32850.0  33.567351 -112.053591
# 20  PHX85021      Phoenix  Maricopa     37743.0  33.559421 -112.092875
# 21  PHX85022      Phoenix  Maricopa     46395.0  33.627240 -112.048414
# 22  PHX85023      Phoenix  Maricopa     31274.0  33.634118 -112.093163
# 23  PHX85024      Phoenix  Maricopa     22898.0  33.736104 -112.029599
# 25  PHX85027      Phoenix  Maricopa     37140.0  33.679761 -112.092529
# 26  PHX85028      Phoenix  Maricopa     19157.0  33.575740 -112.008409
# 27  PHX85029      Phoenix  Maricopa     43233.0  33.594738 -112.109861
# 29  PHX85031      Phoenix  Maricopa     30493.0  33.493971 -112.166926
# 30  PHX85032      Phoenix  Maricopa     65485.0  33.625920 -112.002503
# 31  PHX85033      Phoenix  Maricopa     53037.0  33.492969 -112.209757
#
#     Cluster Labels
# 0                1
# 1                1
# 2                5
# 3                1
# 4                1
# 6                5
# 7                1
# 8                1
# 9                1
# 10               5
# 11               1
# 12               5
# 13               1
# 14               5
# 15               5
# 16               3
# 17               6
# 18               1
# 19               7
# 20               3
# 21               1
# 22               1
# 23               3
# 24               1
# 25               1
# 26               1
# 27               5
# 28               2
# 29               1
# 30               1
# ..             ...
# 59               1
# 60               5
# 61               1
# 62               5
# 64               1
# 2                1
# 3                1
# 5                1
# 6                1
# 7                1
# 8                1
# 11               0
# 12               1
# 13               1
# 14               1
# 15               1
# 16               1
# 17               1
# 18               1
# 19               4
# 20               9
# 21               1
# 22               1
# 23               6
# 25               1
# 26               1
# 27               8
# 5   PHX85006      Phoenix  Maricopa     25742.0  33.465234 -112.048771
# 6   PHX85007      Phoenix  Maricopa     14040.0  33.447614 -112.090883
# 7   PHX85008      Phoenix  Maricopa     56145.0  33.462954 -111.985178
# 8   PHX85009      Phoenix  Maricopa     52520.0  33.443097 -112.128136
# 11  PHX85012      Phoenix  Maricopa      6390.0  33.507577 -112.070981
# 12  PHX85013      Phoenix  Maricopa     19314.0  33.511113 -112.084731
# 13  PHX85014      Phoenix  Maricopa     24782.0  33.507223 -112.057690
# 14  PHX85015      Phoenix  Maricopa     37644.0  33.508664 -112.102018
# 15  PHX85016      Phoenix  Maricopa     33896.0  33.513390 -112.029228
# 16  PHX85017      Phoenix  Maricopa     38872.0  33.508782 -112.123068
# 17  PHX85018      Phoenix  Maricopa     36065.0  33.505956 -111.985386
# 18  PHX85019      Phoenix  Maricopa     25042.0  33.508109 -112.144920
# 19  PHX85020      Phoenix  Maricopa     32850.0  33.567351 -112.053591
# 20  PHX85021      Phoenix  Maricopa     37743.0  33.559421 -112.092875
# 21  PHX85022      Phoenix  Maricopa     46395.0  33.627240 -112.048414
# 22  PHX85023      Phoenix  Maricopa     31274.0  33.634118 -112.093163
# 23  PHX85024      Phoenix  Maricopa     22898.0  33.736104 -112.029599
# 25  PHX85027      Phoenix  Maricopa     37140.0  33.679761 -112.092529
# 26  PHX85028      Phoenix  Maricopa     19157.0  33.575740 -112.008409
# 27  PHX85029      Phoenix  Maricopa     43233.0  33.594738 -112.109861
# 29  PHX85031      Phoenix  Maricopa     30493.0  33.493971 -112.166926
# 30  PHX85032      Phoenix  Maricopa     65485.0  33.625920 -112.002503
# 31  PHX85033      Phoenix  Maricopa     53037.0  33.492969 -112.209757
#
#     Cluster Labels            1st Most Common Venue 2nd Most Common Venue  \
# 0                1               Mexican Restaurant   Fried Chicken Joint
# 1                1                   Discount Store    Mexican Restaurant
# 2                5  Southern / Soul Food Restaurant   Fried Chicken Joint
# 3                1                           Bakery           Art Gallery
# 4                1                            Hotel            Steakhouse
# 6                5             Fast Food Restaurant    Mexican Restaurant
# 7                1             Fast Food Restaurant                 Hotel
# 8                1                      Pizza Place        Ice Cream Shop
# 9                1                           Buffet           Yoga Studio
# 10               5                              NaN                   NaN
# 11               1               Mexican Restaurant        Shipping Store
# 12               5               Mexican Restaurant  Fast Food Restaurant
# 13               1                              NaN                   NaN
# 14               5                     Burger Joint           Yoga Studio
# 15               5                   Airport Lounge      Airport Terminal
# 16               3               Seafood Restaurant            Food Truck
# 17               6                            Hotel                Casino
# 18               1                              NaN                   NaN
# 19               7                Convenience Store           Flea Market
# 20               3                              NaN                   NaN
# 21               1                              NaN                   NaN
# 22               1                Convenience Store        Discount Store
# 23               3                          Stables           Flea Market
# 24               1                      Video Store    Mexican Restaurant
# 25               1                            Track      Airport Terminal
# 26               1               Mexican Restaurant  Fast Food Restaurant
# 27               5                      Music Store           Wings Joint
# 28               2                            Hotel        Sandwich Place
# 29               1                           Bakery           Pizza Place
# 30               1                    Grocery Store            Donut Shop
# ..             ...                              ...                   ...
# 59               1                             Pool           Yoga Studio
# 60               5                              NaN                   NaN
# 61               1                              NaN                   NaN
# 62               5                              NaN                   NaN
# 64               1                              NaN                   NaN
# 2                1              American Restaurant           Music Venue
# 3                1                      Coffee Shop           Pizza Place
# 5                1               Mexican Restaurant            Taco Place
# 6                1                       Food Truck    Athletics & Sports
# 7                1                     Burger Joint              Pharmacy
# 8                1               Mexican Restaurant         Auto Workshop
# 11               0                         Boutique           Pizza Place
# 12               1                   Cosmetics Shop                  Park
# 13               1                      Pizza Place         Moving Target
# 14               1                      Record Shop   Fried Chicken Joint
# 15               1                      Coffee Shop   American Restaurant
# 16               1              Rental Car Location     Convenience Store
# 17               1                      Coffee Shop  Fast Food Restaurant
# 18               1                  Automotive Shop        Rental Service
# 19               4               Mexican Restaurant         Bowling Alley
# 20               9                             Park   American Restaurant
# 21               1                            Trail           Yoga Studio
# 22               1                        Racetrack       Warehouse Store
# 23               6                              NaN                   NaN
# 25               1                       Bagel Shop             BBQ Joint
# 26               1                     Intersection           Flea Market
# 27               8                        BBQ Joint            Hookah Bar
# 29               3             Fast Food Restaurant    Chinese Restaurant
# 30               1                             Park          Intersection
# 31               4                      Bus Station           Yoga Studio
#
#          3rd Most Common Venue   4th Most Common Venue  \
# 0           Chinese Restaurant             Coffee Shop
# 1                    BBQ Joint    Fast Food Restaurant
# 2           Mexican Restaurant    Gym / Fitness Center
# 3                       Lounge                     Bar
# 4                          Bar                 Theater
# 6          Fried Chicken Joint             Pizza Place
# 7                    BBQ Joint                Dive Bar
# 8                   Art Museum                     Gym
# 9                  Flower Shop             Gas Station
# 10                         NaN                     NaN
# 11      Furniture / Home Store       Mobile Phone Shop
# 12              Ice Cream Shop       Food & Drink Shop
# 13                         NaN                     NaN
# 14         American Restaurant                  Bakery
# 15         Rental Car Location          Massage Studio
# 16                 Karaoke Bar             Flower Shop
# 17           Electronics Store        Asian Restaurant
# 18                         NaN                     NaN
# 19                 Gas Station  Furniture / Home Store
# 20                         NaN                     NaN
# 21                         NaN                     NaN
# 22          Mexican Restaurant             Yoga Studio
# 23                 Gas Station  Furniture / Home Store
# 24                    Pharmacy       Convenience Store
# 25                       Hotel                  Hostel
# 26           Convenience Store          Ice Cream Shop
# 27  Construction & Landscaping              Food Truck
# 28                 Yoga Studio    Fast Food Restaurant
# 29                   Rock Club            Home Service
# 30                 Yoga Studio             Flea Market
# ..                         ...                     ...
# 59                 Flea Market             Gas Station
# 60                         NaN                     NaN
# 61                         NaN                     NaN
# 62                         NaN                     NaN
# 64                         NaN                     NaN
# 2                  Coffee Shop                     Pub
# 3          American Restaurant                   Hotel
# 5                         Café             Yoga Studio
# 6           Chinese Restaurant          Breakfast Spot
# 7         Fast Food Restaurant          Sandwich Place
# 8                  Yoga Studio             Flower Shop
# 11      Furniture / Home Store             Coffee Shop
# 12                 Coffee Shop            Cocktail Bar
# 13         Arts & Crafts Store               Pet Store
# 14              Discount Store        Asian Restaurant
# 15              Cosmetics Shop          Clothing Store
# 16        Fast Food Restaurant          Cosmetics Shop
# 17      Gluten-free Restaurant           Shopping Mall
# 18          Mexican Restaurant          Hardware Store
# 19                        Park   General Entertainment
# 20                  Playground             Art Gallery
# 21                 Flea Market             Gas Station
# 22                 Sports Club           Deli / Bodega
# 23                         NaN                     NaN
# 25                 Yoga Studio   General Entertainment
# 26                 Gas Station  Furniture / Home Store
# 27             Bed & Breakfast                    Park
# 29                    Pharmacy          Discount Store
# 30                  Playground             Flea Market
# 31                 Flower Shop             Gas Station
#
#             5th Most Common Venue      6th Most Common Venue  \
# 0                      Food Truck                Bus Station
# 1               Mobile Phone Shop              Grocery Store
# 2                   Historic Site                     Bakery
# 3              Mexican Restaurant                    Brewery
# 4              Seafood Restaurant             Ice Cream Shop
# 6                     Video Store                Flea Market
# 7                     Gas Station  Cajun / Creole Restaurant
# 8                        Pharmacy                  Pet Store
# 9          Furniture / Home Store         Frozen Yogurt Shop
# 10                            NaN                        NaN
# 11             Falafel Restaurant                        Bar
# 12                  Grocery Store             Sandwich Place
# 13                            NaN                        NaN
# 14             Mexican Restaurant                 Food Court
# 15                    Yoga Studio                Flea Market
# 16  Paper / Office Supplies Store             Sandwich Place
# 17             Mexican Restaurant                Yoga Studio
# 18                            NaN                        NaN
# 19             Frozen Yogurt Shop        Fried Chicken Joint
# 20                            NaN                        NaN
# 21                            NaN                        NaN
# 22                    Flower Shop                Gas Station
# 23             Frozen Yogurt Shop        Fried Chicken Joint
# 24            Fried Chicken Joint                 Shoe Store
# 25                            Gym                Flea Market
# 26                 Sandwich Place                 Taco Place
# 27                    Flea Market                Gas Station
# 28         Furniture / Home Store         Frozen Yogurt Shop
# 29                            Bar                    Brewery
# 30         Furniture / Home Store         Frozen Yogurt Shop
# ..                            ...                        ...
# 59         Furniture / Home Store         Frozen Yogurt Shop
# 60                            NaN                        NaN
# 61                            NaN                        NaN
# 62                            NaN                        NaN
# 64                            NaN                        NaN
# 2                     Pizza Place           Sushi Restaurant
# 3                             Bar                        Pub
# 5                      Hobby Shop                  Bike Shop
# 6                  Sandwich Place                       Park
# 7                   Grocery Store                Coffee Shop
# 8                     Gas Station     Furniture / Home Store
# 11                 Breakfast Spot              Deli / Bodega
# 12         Furniture / Home Store                    Gay Bar
# 13                     Restaurant         Chinese Restaurant
# 14             Mexican Restaurant  Cajun / Creole Restaurant
# 15               Department Store    New American Restaurant
# 16                     Taco Place         Mexican Restaurant
# 17                           Bank         Seafood Restaurant
# 18                    Flea Market     Furniture / Home Store
# 19                    Gas Station     Furniture / Home Store
# 20                    Yoga Studio     Furniture / Home Store
# 21         Furniture / Home Store         Frozen Yogurt Shop
# 22               Department Store                Gas Station
# 23                            NaN                        NaN
# 25                    Gas Station     Furniture / Home Store
# 26             Frozen Yogurt Shop        Fried Chicken Joint
# 27                    Yoga Studio                Gas Station
# 29            Japanese Restaurant             Sandwich Place
# 30         Furniture / Home Store         Frozen Yogurt Shop
# 31         Furniture / Home Store         Frozen Yogurt Shop
#
#      7th Most Common Venue   8th Most Common Venue    9th Most Common Venue  \
# 0                     Café           Grocery Store     Fast Food Restaurant
# 1       Chinese Restaurant              Nail Salon              Pizza Place
# 2              Yoga Studio             Flower Shop       Frozen Yogurt Shop
# 31     Fried Chicken Joint       French Restaurant                 Fountain
#
#    10th Most Common Venue
# 0               Pawn Shop
# 1                Pharmacy
# 2       French Restaurant
# 3     Fried Chicken Joint
# 4                   Plaza
# 6                Fountain
# 7            Burger Joint
# 8                    Café
# 9              Food Truck
# 10                    NaN
# 11      French Restaurant
# 12             Smoke Shop
# 13                    NaN
# 14           Cocktail Bar
# 15      French Restaurant
# 16               Fountain
# 17    Fried Chicken Joint
# 18                    NaN
# 19             Food Court
# 20                    NaN
# 21                    NaN
# 22      French Restaurant
# 23             Food Court
# 24            Pizza Place
# 25      French Restaurant
# 26            Bus Station
# 27      French Restaurant
# 28             Food Truck
# 29    Fried Chicken Joint
# 30             Food Truck
# ..                    ...
# 59             Food Truck
# 60                    NaN
# 61                    NaN
# 62                    NaN
# 64                    NaN
# 2               Rock Club
# 3      Salon / Barbershop
# 5                 Gay Bar
# 6             Flower Shop
# 7                    Pool
# 8                Fountain
# 11            Candy Store
# 12        Thai Restaurant
# 13           Dessert Shop
# 14      French Restaurant
# 15                    Spa
# 16               Creperie
# 17    Indie Movie Theater
# 18               Fountain
# 19               Fountain
# 20               Fountain
# 21             Food Truck
# 22      French Restaurant
# 23                    NaN
# 25               Fountain
# 26             Food Court
# 27      French Restaurant
# 29              Pawn Shop
# 30             Food Truck
# 31             Food Truck
#
# [86 rows x 17 columns]

# %%
all_merged.sort_values(['Cluster Labels','City', 'Zipcode', '1st Most Common Venue','2nd Most Common Venue'])
# Out:
#      Zipcode         City    County  Population   latitude   longitude  \
# 11  PHX85012      Phoenix  Maricopa      6390.0  33.507577 -112.070981
# 31   SA78232  San Antonio     Bexar     35120.0  29.588638  -98.474585
# 34   SA78235  San Antonio     Bexar       357.0  29.345382  -98.443402
# 57   SA78258  San Antonio     Bexar     40586.0  29.634097  -98.497426
# 2   PHX85003      Phoenix  Maricopa      9369.0  33.450662 -112.078353
# 3   PHX85004      Phoenix  Maricopa      4965.0  33.451567 -112.069886
# 5   PHX85006      Phoenix  Maricopa     25742.0  33.465234 -112.048771
# 6   PHX85007      Phoenix  Maricopa     14040.0  33.447614 -112.090883
# 7   PHX85008      Phoenix  Maricopa     56145.0  33.462954 -111.985178
# 8   PHX85009      Phoenix  Maricopa     52520.0  33.443097 -112.128136
# 12  PHX85013      Phoenix  Maricopa     19314.0  33.511113 -112.084731
# 13  PHX85014      Phoenix  Maricopa     24782.0  33.507223 -112.057690
# 14  PHX85015      Phoenix  Maricopa     37644.0  33.508664 -112.102018
# 15  PHX85016      Phoenix  Maricopa     33896.0  33.513390 -112.029228
# 16  PHX85017      Phoenix  Maricopa     38872.0  33.508782 -112.123068
# 17  PHX85018      Phoenix  Maricopa     36065.0  33.505956 -111.985386
# 18  PHX85019      Phoenix  Maricopa     25042.0  33.508109 -112.144920
# 21  PHX85022      Phoenix  Maricopa     46395.0  33.627240 -112.048414
# 22  PHX85023      Phoenix  Maricopa     31274.0  33.634118 -112.093163
# 25  PHX85027      Phoenix  Maricopa     37140.0  33.679761 -112.092529
# 26  PHX85028      Phoenix  Maricopa     19157.0  33.575740 -112.008409
# 2                1              American Restaurant           Music Venue
# 3                1                      Coffee Shop           Pizza Place
# 5                1               Mexican Restaurant            Taco Place
# 6                1                       Food Truck    Athletics & Sports
# 7                1                     Burger Joint              Pharmacy
# 8                1               Mexican Restaurant         Auto Workshop
# 12               1                   Cosmetics Shop                  Park
# 13               1                      Pizza Place         Moving Target
# 14               1                      Record Shop   Fried Chicken Joint
# 15               1                      Coffee Shop   American Restaurant
# 16               1              Rental Car Location     Convenience Store
# 17               1                      Coffee Shop  Fast Food Restaurant
# 18               1                  Automotive Shop        Rental Service
# 21               1                            Trail           Yoga Studio
# 22               1                        Racetrack       Warehouse Store
# 25               1                       Bagel Shop             BBQ Joint
# 26               1                     Intersection           Flea Market
# 30               1                             Park          Intersection
# 0                1               Mexican Restaurant   Fried Chicken Joint
# 1                1                   Discount Store    Mexican Restaurant
# 3                1                           Bakery           Art Gallery
# 4                1                            Hotel            Steakhouse
# 7                1             Fast Food Restaurant                 Hotel
# 8                1                      Pizza Place        Ice Cream Shop
# 9                1                           Buffet           Yoga Studio
# 11               1               Mexican Restaurant        Shipping Store
# ..             ...                              ...                   ...
# 39               2                    Grocery Store          Liquor Store
# 29               3             Fast Food Restaurant    Chinese Restaurant
# 16               3               Seafood Restaurant            Food Truck
# 20               3                              NaN                   NaN
# 23               3                          Stables           Flea Market
# 19               4               Mexican Restaurant         Bowling Alley
# 31               4                      Bus Station           Yoga Studio
# 2                5  Southern / Soul Food Restaurant   Fried Chicken Joint
# 6                5             Fast Food Restaurant    Mexican Restaurant
# 10               5                              NaN                   NaN
# 12               5               Mexican Restaurant  Fast Food Restaurant
# 14               5                     Burger Joint           Yoga Studio
# 15               5                   Airport Lounge      Airport Terminal
# 27               5                      Music Store           Wings Joint
# 41               5              American Restaurant        Discount Store
# 42               5                Convenience Store        Sandwich Place
# 43               5                             Pool           Yoga Studio
# 47               5             Gym / Fitness Center              Pharmacy
# 51               5                              NaN                   NaN
# 52               5                              NaN                   NaN
# 58               5       Construction & Landscaping           Yoga Studio
# 60               5                              NaN                   NaN
# 62               5                              NaN                   NaN
# 23               6                              NaN                   NaN
# 17               6                            Hotel                Casino
# 32               6                  Warehouse Store                 Hotel
# 37               6                   Clothing Store            Shoe Store
# 19               7                Convenience Store           Flea Market
# 27               8                        BBQ Joint            Hookah Bar
# 20               9                             Park   American Restaurant
#
#          3rd Most Common Venue   4th Most Common Venue  \
# 11      Furniture / Home Store             Coffee Shop
# 31          Mexican Restaurant      Chinese Restaurant
# 34                 Yoga Studio             Flea Market
# 57                 Yoga Studio             Flea Market
# 2                  Coffee Shop                     Pub
# 3          American Restaurant                   Hotel
# 5                         Café             Yoga Studio
# 6           Chinese Restaurant          Breakfast Spot
# 7         Fast Food Restaurant          Sandwich Place
# 8                  Yoga Studio             Flower Shop
# 12                 Coffee Shop            Cocktail Bar
# 13         Arts & Crafts Store               Pet Store
# 14              Discount Store        Asian Restaurant
# 15              Cosmetics Shop          Clothing Store
# 16        Fast Food Restaurant          Cosmetics Shop
# 17      Gluten-free Restaurant           Shopping Mall
# 18          Mexican Restaurant          Hardware Store
# 21                 Flea Market             Gas Station
# 22                 Sports Club           Deli / Bodega
# 25                 Yoga Studio   General Entertainment
# 26                 Gas Station  Furniture / Home Store
# 30                  Playground             Flea Market
# 0           Chinese Restaurant             Coffee Shop
# 1                    BBQ Joint    Fast Food Restaurant
# 3                       Lounge                     Bar
# 4                          Bar                 Theater
# 7                    BBQ Joint                Dive Bar
# 8                   Art Museum                     Gym
# 9                  Flower Shop             Gas Station
# 11      Furniture / Home Store       Mobile Phone Shop
# ..                         ...                     ...
# 39                 Pizza Place      Salon / Barbershop
# 29                    Pharmacy          Discount Store
# 16                 Karaoke Bar             Flower Shop
# 20                         NaN                     NaN
# 23                 Gas Station  Furniture / Home Store
# 19                        Park   General Entertainment
# 31                 Flower Shop             Gas Station
# 2           Mexican Restaurant    Gym / Fitness Center
# 6          Fried Chicken Joint             Pizza Place
# 10                         NaN                     NaN
# 12              Ice Cream Shop       Food & Drink Shop
# 14         American Restaurant                  Bakery
# 15         Rental Car Location          Massage Studio
# 27  Construction & Landscaping              Food Truck
# 41                 Auto Garage                    Food
# 42        Gym / Fitness Center                   Trail
# 43                 Flea Market             Gas Station
# 47                    Building        Sushi Restaurant
# 51                         NaN                     NaN
# 52                         NaN                     NaN
# 58                 Flea Market             Gas Station
# 60                         NaN                     NaN
# 62                         NaN                     NaN
# 23                         NaN                     NaN
# 17           Electronics Store        Asian Restaurant
# 32           Other Repair Shop             Yoga Studio
# 37              Cosmetics Shop       Accessories Store
# 19                 Gas Station  Furniture / Home Store
# 27             Bed & Breakfast                    Park
# 20                  Playground             Art Gallery
#
#             5th Most Common Venue      6th Most Common Venue  \
# 11                 Breakfast Spot              Deli / Bodega
# 31                     Bagel Shop       Gym / Fitness Center
# 34         Furniture / Home Store         Frozen Yogurt Shop
# 57         Furniture / Home Store         Frozen Yogurt Shop
# 2                     Pizza Place           Sushi Restaurant
# 3                             Bar                        Pub
# 5                      Hobby Shop                  Bike Shop
# 6                  Sandwich Place                       Park
# 7                   Grocery Store                Coffee Shop
# 8                     Gas Station     Furniture / Home Store
# 12         Furniture / Home Store                    Gay Bar
# 13                     Restaurant         Chinese Restaurant
# 14             Mexican Restaurant  Cajun / Creole Restaurant
# 15               Department Store    New American Restaurant
# 16                     Taco Place         Mexican Restaurant
# 17                           Bank         Seafood Restaurant
# 18                    Flea Market     Furniture / Home Store
# 21         Furniture / Home Store         Frozen Yogurt Shop
# 22               Department Store                Gas Station
# 25                    Gas Station     Furniture / Home Store
# 26             Frozen Yogurt Shop        Fried Chicken Joint
# 30         Furniture / Home Store         Frozen Yogurt Shop
# 0                      Food Truck                Bus Station
# 1               Mobile Phone Shop              Grocery Store
# 3              Mexican Restaurant                    Brewery
# 4              Seafood Restaurant             Ice Cream Shop
# 7                     Gas Station  Cajun / Creole Restaurant
# 8                        Pharmacy                  Pet Store
# 9          Furniture / Home Store         Frozen Yogurt Shop
# 11             Falafel Restaurant                        Bar
# ..                            ...                        ...
# 39              Mobile Phone Shop                Flea Market
# 29            Japanese Restaurant             Sandwich Place
# 16  Paper / Office Supplies Store             Sandwich Place
# 20                            NaN                        NaN
# 23             Frozen Yogurt Shop        Fried Chicken Joint
# 19                    Gas Station     Furniture / Home Store
# 31         Furniture / Home Store         Frozen Yogurt Shop
# 2                   Historic Site                     Bakery
# 6                     Video Store                Flea Market
# 10                            NaN                        NaN
# 12                  Grocery Store             Sandwich Place
# 14             Mexican Restaurant                 Food Court
# 15                    Yoga Studio                Flea Market
# 27                    Flea Market                Gas Station
# 41                    Yoga Studio                Flower Shop
# 42           Fast Food Restaurant         Frozen Yogurt Shop
# 43         Furniture / Home Store         Frozen Yogurt Shop
# 47                 Sandwich Place                     Lounge
# 51                            NaN                        NaN
# 52                            NaN                        NaN
# 58         Furniture / Home Store         Frozen Yogurt Shop
# 60                            NaN                        NaN
# 62                            NaN                        NaN
# 23                            NaN                        NaN
# 17             Mexican Restaurant                Yoga Studio
# 32           Fast Food Restaurant         Frozen Yogurt Shop
# 37              Mobile Phone Shop         Chinese Restaurant
# 19             Frozen Yogurt Shop        Fried Chicken Joint
# 27                    Yoga Studio                Gas Station
# 20                    Yoga Studio     Furniture / Home Store
#
#       7th Most Common Venue   8th Most Common Venue    9th Most Common Venue  \
# 11           Clothing Store             Record Shop       Mexican Restaurant
# 31  Health & Beauty Service              Taco Place     Fast Food Restaurant
# 34      Fried Chicken Joint       French Restaurant                 Fountain
# 57      Fried Chicken Joint       French Restaurant                 Fountain
# 2             Bowling Alley                Building             Burger Joint
# 3                      Park          Sandwich Place                Hotel Bar
# 5               Gas Station    Fast Food Restaurant           Clothing Store
# 6                     Plaza       French Restaurant                 Fountain
# 7                       Gym             Pizza Place        French Restaurant
# 8        Frozen Yogurt Shop     Fried Chicken Joint        French Restaurant
# 12        Mobile Phone Shop          Sandwich Place               Taco Place
# 13                     Café        Sushi Restaurant       Mexican Restaurant
# 14              Flower Shop  Furniture / Home Store       Frozen Yogurt Shop
# 15             Burger Joint                Boutique      Sporting Goods Shop
# 16       Seafood Restaurant                   Diner         Department Store
# 17               Restaurant             Gas Station      American Restaurant
# 18       Frozen Yogurt Shop     Fried Chicken Joint        French Restaurant
# 21      Fried Chicken Joint       French Restaurant                 Fountain
# 22   Furniture / Home Store      Frozen Yogurt Shop      Fried Chicken Joint
# 25       Frozen Yogurt Shop     Fried Chicken Joint        French Restaurant
# 26        French Restaurant                Fountain               Food Truck
# 30      Fried Chicken Joint       French Restaurant                 Fountain
# 0                      Café           Grocery Store     Fast Food Restaurant
# 1        Chinese Restaurant              Nail Salon              Pizza Place
# 3               Pizza Place       Recreation Center       Frozen Yogurt Shop
# 4             Historic Site          History Museum             Dessert Shop
# 7        Mexican Restaurant      Chinese Restaurant        Convenience Store
# 8            Clothing Store      Salon / Barbershop          Organic Grocery
# 9       Fried Chicken Joint       French Restaurant                 Fountain
# 11              Yoga Studio      Frozen Yogurt Shop      Fried Chicken Joint
# ..                      ...                     ...                      ...
# 39       Frozen Yogurt Shop     Fried Chicken Joint        French Restaurant
# 29        Mobile Phone Shop              Restaurant               Sports Bar
# 16              Yoga Studio     Fried Chicken Joint        French Restaurant
# 20                      NaN                     NaN                      NaN
# 23        French Restaurant                Fountain               Food Truck
# 19       Frozen Yogurt Shop     Fried Chicken Joint        French Restaurant
# 31      Fried Chicken Joint       French Restaurant                 Fountain
# 2               Yoga Studio             Flower Shop       Frozen Yogurt Shop
# 6    Furniture / Home Store      Frozen Yogurt Shop        French Restaurant
# 10                      NaN                     NaN                      NaN
# 12       Salon / Barbershop               Pawn Shop             Liquor Store
# 14              Coffee Shop                  Museum  New American Restaurant
# 15   Furniture / Home Store      Frozen Yogurt Shop      Fried Chicken Joint
# 27   Furniture / Home Store      Frozen Yogurt Shop      Fried Chicken Joint
# 41              Gas Station  Furniture / Home Store       Frozen Yogurt Shop
# 42      Fried Chicken Joint       French Restaurant                 Fountain
# 43      Fried Chicken Joint       French Restaurant                 Fountain
# 47       Chinese Restaurant             Dry Cleaner                      Spa
# 51                      NaN                     NaN                      NaN
# 52                      NaN                     NaN                      NaN
# 58      Fried Chicken Joint       French Restaurant                 Fountain
# 60                      NaN                     NaN                      NaN
# 62                      NaN                     NaN                      NaN
# 23                      NaN                     NaN                      NaN
# 17              Gas Station  Furniture / Home Store       Frozen Yogurt Shop
# 32      Fried Chicken Joint       French Restaurant                 Fountain
# 37            Women's Store        Department Store       Italian Restaurant
# 19        French Restaurant                Fountain               Food Truck
# 27   Furniture / Home Store      Frozen Yogurt Shop      Fried Chicken Joint
# 20       Frozen Yogurt Shop     Fried Chicken Joint        French Restaurant
#
#    10th Most Common Venue
# 11            Candy Store
# 31    Rental Car Location
# 34             Food Truck
# 57             Food Truck
# 2               Rock Club
# 3      Salon / Barbershop
# 5                 Gay Bar
# 6             Flower Shop
# 7                    Pool
# 8                Fountain
# 12        Thai Restaurant
# 13           Dessert Shop
# 14      French Restaurant
# 15                    Spa
# 16               Creperie
# 17    Indie Movie Theater
# 18               Fountain
# 21             Food Truck
# 22      French Restaurant
# 25               Fountain
# 26             Food Court
# 30             Food Truck
# 0               Pawn Shop
# 1                Pharmacy
# 3     Fried Chicken Joint
# 4                   Plaza
# 7            Burger Joint
# 8                    Café
# 9              Food Truck
# 11      French Restaurant
# ..                    ...
# 39               Fountain
# 29              Pawn Shop
# 16               Fountain
# 20                    NaN
# 23             Food Court
# 19               Fountain
# 31             Food Truck
# 2       French Restaurant
# 6                Fountain
# 10                    NaN
# 12             Smoke Shop
# 14           Cocktail Bar
# 15      French Restaurant
# 27      French Restaurant
# 41    Fried Chicken Joint
# 42             Food Truck
# 43             Food Truck
# 47      Convenience Store
# 51                    NaN
# 52                    NaN
# 58             Food Truck
# 60                    NaN
# 62                    NaN
# 23                    NaN
# 17    Fried Chicken Joint
# 32             Food Truck
# 37       Toy / Game Store
# 19             Food Court
# 27      French Restaurant
# 20               Fountain
#
# [86 rows x 17 columns]

# %%
all_merged.to_excel("SA_PHX_compare.xlsx")

# %%
#The project token is an authorization token that is used to access project resources like data sources, connections, and used by platform APIs.
#from project_lib import Project
#project = Project(None, 'Capstone','p-bb84538548e5617dea7c8536cefe1485f6da66b3')
#pc = project.project_context
#project.save_data(data=all_merged.to_csv(index=False),file_name='SA_PHX_compare.csv',overwrite=True)
